# %% [markdown]
# # Review Python Language

# %%
print("Hello world")
# Out:
# Hello world

# %%
my_name = "FA"
my_age = 27

# %%
print(my_name)
# Out:
# FA

# %%
# String & string in python
my_university = "CMU"
my_long_string = """This is a very long
    This is a second line
    this is a third line
"""

print(my_name,my_age,my_university,my_long_string)
# Out:
# FA 27 CMU This is a very long
#     This is a second line
#     this is a third line

# %%
# fstring template
my_name = "FA"
my_age = 27

text = f"My name is {my_name}, and I am {my_age} years old."
print(text)
# Out:
# My name is FA, and I am 27 years old.

# %%
# function designed for string (string methods)
text = "a duck walks into a bar"

# %%
text.upper()
# Out:
# 'A DUCK WALKS INTO A BAR'

# %%
"HELLO WORLD".lower()
# Out:
# 'hello world'

# %%
text.count("a")
# Out:
# 4

# %%
text2 = text.replace("duck","lion")
print(text2)
# Out:
# a lion walks into a bar

# %%
# list
shopping_list = ["egg", "milk", "bread"]
print(shopping_list)
# Out:
# ['egg', 'milk', 'bread']

# %%
print(shopping_list[0])
# Out:
# egg

# %%
print(shopping_list[0:2])
# Out:
# ['egg', 'milk']

# %%
# list method = append

shopping_list.append("orange juice")

print(shopping_list)
# Out:
# ['egg', 'milk', 'bread', 'orange juice']

# %%
# list method = .pop()
shopping_list.pop()
# Out:
# 'orange juice'

# %%
print(shopping_list)
# Out:
# ['egg', 'milk', 'bread']

# %%
len(shopping_list)
# Out:
# 3

# %%
# dictionary key-value pair
student = {
    "id" : 1,
    "name" : "Marry",
    "age" : 22,
    "movies" : ["Spider Man", "Thor", "Iron Man 3"]
}

# %%
student
# Out:
# {'id': 1,
#  'name': 'Marry',
#  'age': 22,
#  'movies': ['Spider Man', 'Thor', 'Iron Man 3']}

# %%
type(student)
# Out:
# dict

# %%
student["movies"]
# Out:
# ['Spider Man', 'Thor', 'Iron Man 3']

# %%
student["movies"][1]
# Out:
# 'Thor'

# %%
student["city"] = "London"

# %%
student
# Out:
# {'id': 1,
#  'name': 'Marry',
#  'age': 22,
#  'movies': ['Spider Man', 'Thor', 'Iron Man 3'],
#  'city': 'London'}

# %%
# update value
student["city"] = "Manchester"
student
# Out:
# {'id': 1,
#  'name': 'Marry',
#  'age': 22,
#  'movies': ['Spider Man', 'Thor', 'Iron Man 3'],
#  'city': 'Manchester'}

# %%
# remove key-value
del student["city"]
student
# Out:
# {'id': 1,
#  'name': 'Marry',
#  'age': 22,
#  'movies': ['Spider Man', 'Thor', 'Iron Man 3']}

# %%
# user-defined function 
def hello():
    print("Hello!")
    print("I am learning Python")

# %%
hello()
# Out:
# Hello!
# I am learning Python

# %%
def hello(username):
    print("Hello!" + username)

# %%
hello("Fa")
# Out:
# Hello!Fa

# %%
def my_sum(x,y):
    print(x+y)

# %%
my_sum(5,3)
# Out:
# 8

# %%
def my_sum(x,y):
    return x+y
result = my_sum(5,3)
print(result)
# Out:
# 8

# %% [markdown]
# # **OOP**
# Object Oriented Programming

# %%
class Dog:
    name = "Micky"
    age = 3
    color = "Black"
    breed = "French Bulldog"

# %%
my_dog = Dog()
type(my_dog)
# Out:
# __main__.Dog

# %%
my_dog.breed
# Out:
# 'French Bulldog'
