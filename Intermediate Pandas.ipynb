# %%
import pandas as pd

# %%
penguins = pd.read_csv("penguins.csv")

# %%
penguins.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.1</td>
#       <td>18.7</td>
#       <td>181.0</td>
#       <td>3750.0</td>
#       <td>MALE</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.5</td>
#       <td>17.4</td>
#       <td>186.0</td>
#       <td>3800.0</td>
# ...

# %%
# preview last 5 rowa
penguins.tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>339</th>
#       <td>Gentoo</td>
#       <td>Biscoe</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>340</th>
#       <td>Gentoo</td>
#       <td>Biscoe</td>
#       <td>46.8</td>
#       <td>14.3</td>
#       <td>215.0</td>
#       <td>4850.0</td>
#       <td>FEMALE</td>
# ...

# %%
# shape of dataframe
penguins.shape
# Out:
# (344, 7)

# %%
# information of dataframe
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# select column
penguins["species"]
# Out:
# <pre>0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object</pre>

# %%
# select column
penguins.species.head()
# Out:
# <pre>0    Adelie
# 1    Adelie
# 2    Adelie
# 3    Adelie
# 4    Adelie
# Name: species, dtype: object</pre>

# %%
# select column
penguins[["species","island","sex"]].head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>MALE</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>FEMALE</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>FEMALE</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Adelie</td>
# ...

# %%
penguins[["species","island","sex"]].tail(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>334</th>
#       <td>Gentoo</td>
#       <td>Biscoe</td>
#       <td>FEMALE</td>
#     </tr>
#     <tr>
#       <th>335</th>
#       <td>Gentoo</td>
#       <td>Biscoe</td>
#       <td>MALE</td>
#     </tr>
#     <tr>
#       <th>336</th>
#       <td>Gentoo</td>
#       <td>Biscoe</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>337</th>
#       <td>Gentoo</td>
#       <td>Biscoe</td>
#       <td>MALE</td>
#     </tr>
#     <tr>
#       <th>338</th>
#       <td>Gentoo</td>
# ...

# %%
# integer location based indexing (iloc=row)
penguins.iloc[0]
penguins.iloc[[0,1,2]]
penguins.iloc[0:3]
penguins.iloc[0:5,[0,1,2]]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>40.3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Adelie</td>
# ...

# %%
# filter rows by a condition
penguins[penguins["island"] == "Torgersen"]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.1</td>
#       <td>18.7</td>
#       <td>181.0</td>
#       <td>3750.0</td>
#       <td>MALE</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.5</td>
#       <td>17.4</td>
#       <td>186.0</td>
#       <td>3800.0</td>
# ...

# %%
# filter rows by a condition
penguins[penguins["bill_length_mm"] < 34]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>70</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>33.5</td>
#       <td>19.0</td>
#       <td>190.0</td>
#       <td>3600.0</td>
#       <td>FEMALE</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>Adelie</td>
#       <td>Dream</td>
#       <td>33.1</td>
#       <td>16.1</td>
#       <td>178.0</td>
#       <td>2900.0</td>
# ...

# %%
# filter more than one condition
penguins[(penguins["island"] == "Torgersen") & (penguins["bill_length_mm"] < 35)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>34.1</td>
#       <td>18.1</td>
#       <td>193.0</td>
#       <td>3475.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>34.6</td>
#       <td>21.1</td>
#       <td>198.0</td>
#       <td>4400.0</td>
# ...

# %%
# filter more than one condition
penguins[(penguins["island"] == "Torgersen") | (penguins["bill_length_mm"] < 34)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.1</td>
#       <td>18.7</td>
#       <td>181.0</td>
#       <td>3750.0</td>
#       <td>MALE</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.5</td>
#       <td>17.4</td>
#       <td>186.0</td>
#       <td>3800.0</td>
# ...

# %%
# filter with .query()
penguins.query("island == 'Torgersen'")
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.1</td>
#       <td>18.7</td>
#       <td>181.0</td>
#       <td>3750.0</td>
#       <td>MALE</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.5</td>
#       <td>17.4</td>
#       <td>186.0</td>
#       <td>3800.0</td>
# ...

# %%
# filter with .query()
penguins.query("island == 'Torgersen' & bill_length_mm < 35")
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>34.1</td>
#       <td>18.1</td>
#       <td>193.0</td>
#       <td>3475.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>34.6</td>
#       <td>21.1</td>
#       <td>198.0</td>
#       <td>4400.0</td>
# ...

# %%
# check missing in each column
penguins.isna().sum()
# Out:
# <pre>species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64</pre>

# %%
# filter missing value in column sex
penguins[penguins["sex"].isna()]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>34.1</td>
#       <td>18.1</td>
#       <td>193.0</td>
#       <td>3475.0</td>
#       <td>NaN</td>
# ...

# %%
# drop na
clean_penguins = penguins.dropna()
clean_penguins.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.1</td>
#       <td>18.7</td>
#       <td>181.0</td>
#       <td>3750.0</td>
#       <td>MALE</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.5</td>
#       <td>17.4</td>
#       <td>186.0</td>
#       <td>3800.0</td>
# ...

# %%
# fill missing value
# Mean imputation = Replace nan with column mean

top5_penguins = penguins.head()
avg_value = top5_penguins["bill_length_mm"].mean()
avg_value
# Out:
# 38.9

# %%
top5_penguins = top5_penguins["bill_length_mm"].fillna(value=avg_value)
top5_penguins
# Out:
# <pre>0    39.1
# 1    39.5
# 2    40.3
# 3    38.9
# 4    36.7
# Name: bill_length_mm, dtype: float64</pre>

# %%
# sort bill length mm low to high, high to low
penguins.sort_values("bill_length_mm")
penguins.sort_values("bill_length_mm", ascending=False)
penguins.dropna().sort_values("bill_length_mm", ascending=False).head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>253</th>
#       <td>Gentoo</td>
#       <td>Biscoe</td>
#       <td>59.6</td>
#       <td>17.0</td>
#       <td>230.0</td>
#       <td>6050.0</td>
#       <td>MALE</td>
#     </tr>
#     <tr>
#       <th>169</th>
#       <td>Chinstrap</td>
#       <td>Dream</td>
#       <td>58.0</td>
#       <td>17.8</td>
#       <td>181.0</td>
#       <td>3700.0</td>
# ...

# %%
# sort multiple column

penguins.dropna().sort_values(["island","bill_length_mm"])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>54</th>
#       <td>Adelie</td>
#       <td>Biscoe</td>
#       <td>34.5</td>
#       <td>18.1</td>
#       <td>187.0</td>
#       <td>2900.0</td>
#       <td>FEMALE</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>Adelie</td>
#       <td>Biscoe</td>
#       <td>35.0</td>
#       <td>17.9</td>
#       <td>190.0</td>
#       <td>3450.0</td>
# ...

# %%
# unique values
penguins["species"].unique()
# Out:
# <pre>array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)</pre>

# %%
# count values
penguins["species"].value_counts()
# Out:
# <pre>Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64</pre>

# %%
# count more than one column
penguins[["island","species"]].value_counts().reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>island</th>
#       <th>species</th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Biscoe</td>
#       <td>Gentoo</td>
#       <td>124</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Dream</td>
#       <td>Chinstrap</td>
#       <td>68</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Dream</td>
#       <td>Adelie</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Torgersen</td>
#       <td>Adelie</td>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Biscoe</td>
#       <td>Adelie</td>
# ...

# %%
result = penguins[["island","species"]].value_counts().reset_index()
result.columns = ["island","species","count"]
result
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>island</th>
#       <th>species</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Biscoe</td>
#       <td>Gentoo</td>
#       <td>124</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Dream</td>
#       <td>Chinstrap</td>
#       <td>68</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Dream</td>
#       <td>Adelie</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Torgersen</td>
#       <td>Adelie</td>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Biscoe</td>
#       <td>Adelie</td>
# ...

# %%
# summarise dataframe

penguins.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>342.000000</td>
#       <td>342.000000</td>
#       <td>342.000000</td>
#       <td>342.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>43.921930</td>
#       <td>17.151170</td>
#       <td>200.915205</td>
#       <td>4201.754386</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>5.459584</td>
#       <td>1.974793</td>
#       <td>14.061714</td>
#       <td>801.954536</td>
#     </tr>
# ...

# %%
penguins.describe(include='all')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>344</td>
#       <td>344</td>
#       <td>342.000000</td>
#       <td>342.000000</td>
#       <td>342.000000</td>
#       <td>342.000000</td>
#       <td>333</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>3</td>
#       <td>3</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2</td>
# ...

# %%
# average, mean

penguins["bill_length_mm"].median()
penguins["bill_length_mm"].mean()
# Out:
# 43.9219298245614

# %%
# group by

penguins.groupby("species")["bill_length_mm"].mean()
# Out:
# <pre>species
# Adelie       38.791391
# Chinstrap    48.833824
# Gentoo       47.504878
# Name: bill_length_mm, dtype: float64</pre>

# %%
# aggregation
penguins.groupby("species")["bill_length_mm"].agg(["min","mean","std","max"])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>min</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>species</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Adelie</th>
#       <td>32.1</td>
#       <td>38.791391</td>
#       <td>2.663405</td>
#       <td>46.0</td>
#     </tr>
#     <tr>
#       <th>Chinstrap</th>
#       <td>40.9</td>
#       <td>48.833824</td>
#       <td>3.339256</td>
#       <td>58.0</td>
#     </tr>
#     <tr>
#       <th>Gentoo</th>
#       <td>40.9</td>
#       <td>47.504878</td>
# ...

# %%
# group by more than one column
penguins.groupby(["island","species"])["bill_length_mm"].agg(["min","mean","max"]).reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>island</th>
#       <th>species</th>
#       <th>min</th>
#       <th>mean</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Biscoe</td>
#       <td>Adelie</td>
#       <td>34.5</td>
#       <td>38.975000</td>
#       <td>45.6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Biscoe</td>
#       <td>Gentoo</td>
#       <td>40.9</td>
#       <td>47.504878</td>
#       <td>59.6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Dream</td>
#       <td>Adelie</td>
#       <td>32.1</td>
#       <td>38.501786</td>
#       <td>44.1</td>
#     </tr>
# ...

# %%
# write result to csv file
result = penguins.groupby(["island","species"])["bill_length_mm"].agg(["min","mean","max"]).reset_index()

result.to_csv("result.csv")

# %%
# if your code is long used \

# group by more than one column
penguins.groupby(["island","species"])\
["bill_length_mm"].agg(["min","mean","max"]).reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>island</th>
#       <th>species</th>
#       <th>min</th>
#       <th>mean</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Biscoe</td>
#       <td>Adelie</td>
#       <td>34.5</td>
#       <td>38.975000</td>
#       <td>45.6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Biscoe</td>
#       <td>Gentoo</td>
#       <td>40.9</td>
#       <td>47.504878</td>
#       <td>59.6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Dream</td>
#       <td>Adelie</td>
#       <td>32.1</td>
#       <td>38.501786</td>
#       <td>44.1</td>
#     </tr>
# ...

# %%
# map values MALE : m, FEMALE : f

penguins["sex"].map({"MALE" : "m" , "FEMALE" : "f"})\
.fillna("other")
# Out:
# <pre>0          m
# 1          f
# 2          f
# 3      other
# 4          f
#        ...
# 339    other
# 340        f
# 341        m
# 342        f
# 343        m
# Name: sex, Length: 344, dtype: object</pre>

# %%
penguins["new_sex"] = penguins["sex"]\
    .map({"MALE" : "m" , "FEMALE" : "f"})\
    .fillna("other")
 
penguins.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#       <th>new_sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.1</td>
#       <td>18.7</td>
#       <td>181.0</td>
#       <td>3750.0</td>
#       <td>MALE</td>
#       <td>m</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.5</td>
#       <td>17.4</td>
#       <td>186.0</td>
# ...

# %%
# Numpy

import numpy as np

# %%
np.mean(penguins["bill_length_mm"])
# Out:
# 43.9219298245614

# %%
np.sum(penguins["bill_depth_mm"])
# Out:
# 5865.700000000001

# %%
df = penguins.query("species == 'Adelie'")[["species","island","bill_length_mm"]].dropna()

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>40.3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>36.7</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Adelie</td>
# ...

# %%
df["new_col"] = np.where(df["bill_length_mm"]>40,True,False)
df.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>new_col</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.1</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.5</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>40.3</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Adelie</td>
# ...
